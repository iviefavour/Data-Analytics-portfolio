# %% [markdown]
# # write a program to show string methods from 21 to the last

# %%
txt = "Hello, Welcome To Canada"
x = txt.istitle()
print(x)
# Out:
# True

# %%
txt = "    i      "
txxt = "  "
x = txt.isspace()
s = txxt.isspace()
print(x)
print(s)
# Out:
# False
# True

# %%
txt = "THE BEST TIME TO EAT BREAKFAST IS IN THE MORNING"

x = txt.isupper()

print(x)
# Out:
# True

# %%
myTuple = ("John", "Tyla", "Paul","Ivie")

x = "#".join(myTuple)

print(x)
# Out:
# John#Tyla#Paul#Ivie

# %%
txt = "mango"

x = txt.ljust(10,)

print(x, "is my best fruit.")
# Out:
# mango      is my best fruit.

# %%
txt = "How Are You Today?"

x = txt.lower()

print(x)
# Out:
# how are you today?

# %%
txt = " cake"

x = txt.lstrip()

print("of all snacks", x, "is my favorite")
# Out:
# of all snacks cake is my favorite

# %%
txt = "Welcome Sarah!"
mytable = str.maketrans("S", "P")
print(txt.translate(mytable))
# Out:
# Welcome Parah!

# %%
txt = "I can sleep all night but not daytime"

x = txt.partition("daytime")

print(x)
# Out:
# ('I can sleep all night but not ', 'daytime', '')

# %%
txt = "I love pear"

x = txt.replace("pear", "apples")

print(x)
# Out:
# I love apples

# %%
txt = "Hello, welcome to my world."

x = txt.rfind("d")

print(x)
# Out:
# 25

# %%
txt = "My everything"

x = txt.rindex("g")

print(x)
# Out:
# 12

# %%
txt = "cake"

x = txt.rjust(10, "L")

print(x, "is my favorite snack.")
# Out:
# LLLLLLcake is my favorite snack.

# %%
txt = "I could eat bananas all day, bananas are my favorite fruit"

x = txt.rpartition("apples")

print(x)
# Out:
# ('', '', 'I could eat bananas all day, bananas are my favorite fruit')

# %%
txt = "apple, pawpaw, cherry"

x = txt.rsplit(", ")

print(x)
# Out:
# ['apple', 'pawpaw', 'cherry']

# %%
txt = "welcome to canada"

x = txt.split()

print(x)
# Out:
# ['welcome', 'to', 'canada']

# %%
txt = "Thank you \nfor the money\nWelcome to my house"

x = txt.splitlines()

print(x)
# Out:
# ['Thank you ', 'for the money', 'Welcome to my house']

# %%
txt = "Hello, welcome to my world."

x = txt.startswith("Hello")

print(x)
# Out:
# True

# %%
txt = "     banana     "

x = txt.strip()

print("of all fruits", x, "is my favorite")
# Out:
# of all fruits banana is my favorite

# %%
txt = "Hello My Name Is Ivie"

x = txt.swapcase()

print(x)
# Out:
# hELLO mY nAME iS iVIE

# %%
txt = "Welcome to my world"

x = txt.title()

print(x)
# Out:
# Welcome To My World

# %%
mydict = {83:  80}
txt = "Hello Sam!"
print(txt.translate(mydict))
# Out:
# Hello Pam!

# %%
txt = "Hello Pen!"
mytable = str.maketrans("P", "H")
print(txt.translate(mytable))
# Out:
# Hello Hen!

# %%
txt = "God bless you"

x = txt.upper()

print(x)
# Out:
# GOD BLESS YOU

# %%
txt = "cyprian"

x = txt.zfill(15)

print(x)
# Out:
# 00000000cyprian
