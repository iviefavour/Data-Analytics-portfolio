# %% [markdown]
# ## Python Assignment
#
# (1) What is pandas in Python, and why is it used in data analysis?
#
# (2) How do you create a Series in pandas? Give an example.
#
# (3) How do you create a DataFrame from a dictionary of lists?
#
# (4) What is the difference between a Series and a DataFrame?
#
# (5) Write code to read a CSV file named sales.csv into a DataFrame.
#
# (6) How do you check the first 5 and last 5 rows of a DataFrame?
#
# (7) What are index and columns in pandas?
#
# (8) How do you get the shape and data types of a DataFrame?
#
# (9) How do you select a single column and multiple columns from a DataFrame?
#
# (10) Explain the difference between head() and tail().Give example

# %%
# (1) What is pandas in Python, and why is it used in data analysis?

# Pandas is a python library used for working with data set. 

# We use pandas in data analysis because it can clean dirty data sets,
# and make them readable and relevant and also allows us to analyze big data 
# and make conclusions based on statistical theories.

# %%
# (2) How do you create a Series in pandas? Give an example.


import pandas as pd

days = ['Chanel','prada','Dior']
ser = pd.Series(days)
print(ser)
# Out:
# 0    Chanel
# 1     prada
# 2      Dior
# dtype: object

# %%
# 3) How do you create a DataFrame from a dictionary of lists?

import pandas as pd
data = {
    "Product_name":['Hair gel','Toner','cleanser'],
    "Amount":[5000,6500,11700]
}
df = pd.DataFrame(data)
print(df)
# Out:
#   Product_name  Amount
# 0     Hair gel    5000
# 1        Toner    6500
# 2     cleanser   11700

# %%
# (4) What is the difference between a Series and a DataFrame?

# A Pandas Series is like a column in a table.
# WHILE
# Pandas DataFrame is used to create tables with rows and columns.

# %%
# (5) Write code to read a CSV file named sales.csv into a DataFrame.

# import pandas as pd
    
# df = pd.read_csv("Alen.csv")
# print(df)

# %%
# (6) How do you check the first 5 and last 5 rows of a DataFrame?
# To check for the first 5 rows of a DataFrame use 'print(df.head(5))' 
# # To check for the first 5 rows of a DataFrame use 'print(df.tail(5))'

# %%
# (7) What are index and columns in pandas?
#  Index argument is used to name your own labels.
#  Columns are the labels of the data fields and each column is basically a pandas Series (like a 1D array).

# %%
# (8) How do you get the shape and data types of a DataFrame?

# To get the shape of a Dataframe use 'df.shape'
# To get the data types of a Dataframe use 'df.dtypes'

# %%
# (9) How do you select a single column and multiple columns from a DataFrame?

# To get a Single column use " df['Product_name'] "
# To get multiple columns use " df[['Product_name','Amount']]"

# %%
# (10) Explain the difference between head() and tail().Give example

# The head() method returns the headers and a specified number of rows, starting from the top.
# WHILE
# The tail() method returns the headers and a specified number of rows, starting from the bottom.


import pandas as pd
data = {
    "Product_name":['Hair gel','Hair oil','Toner','Cleanser'],
    "Amount":[5000,6500,11700,9500]
}
sales = pd.DataFrame(data)
print(sales.head(3))

print(sales.tail(3))
# Out:
#   Product_name  Amount
# 0     Hair gel    5000
# 1     Hair oil    6500
# 2        Toner   11700
#   Product_name  Amount
# 1     Hair oil    6500
# 2        Toner   11700
# 3     Cleanser    9500
